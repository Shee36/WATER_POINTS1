# %%
import pandas as pd

# %%
json = pd.read_json('https://raw.githubusercontent.com/onaio/ona-tech/master/data/water_points.json')

# %%
json.head()
# Out:
#   water_pay respondent research_asst_name water_used_season  \
# 0        no  community    Haruna Mohammed        year_round
# 1        no  community     Haruna Mohmmed        year_round
# 2        no  community    Haruna Mohammed        year_round
# 3        no  community    Haruna Mohammed        year_round
# 4        no  community    Haruna Mohammed        year_round
#
#   _bamboo_dataset_id _deleted_at water_point_condition     _xform_id_string  \
# 0                            NaT           functioning  _08_Water_points_CV
# 1                            NaT           functioning  _08_Water_points_CV
# 2                            NaT           functioning  _08_Water_points_CV
# 3                            NaT           functioning  _08_Water_points_CV
# 4                            NaT           functioning  _08_Water_points_CV
#
#   other_point_1km                                 _attachments  ...  \
# 0              no  [north_ghana/attachments/1351696546452.jpg]  ...
# ...

# %%
water_points = requests.get(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-19746717f27a> in <module>
# ----> 1 water_points = requests.get(url)
#
# NameError: name 'requests' is not defined

# %%
import requests

# %%
url = 'https://raw.githubusercontent.com/onaio/ona-tech/master/data/water_points.json'

# %%
water_points_url = requests.get(url)

# %%
water_points_url
# Out:
# <Response [200]>

# %%
json.tail()
# Out:
#     water_pay                 respondent research_asst_name water_used_season  \
# 707        no                  community         Emmanuel y        year_round
# 708        no  local_authority community         Emmanuel y        year_round
# 709        no  local_authority community         Emmanuel y        year_round
# 710        no                  community          abu seidu        year_round
# 711        no                  community                 Sa        year_round
#
#     _bamboo_dataset_id _deleted_at water_point_condition     _xform_id_string  \
# 707                            NaT           functioning  _08_Water_points_CV
# 708                            NaT                broken  _08_Water_points_CV
# 709                            NaT                broken  _08_Water_points_CV
# 710                            NaT           functioning  _08_Water_points_CV
# 711                            NaT           functioning  _08_Water_points_CV
#
# ...

# %%
json.shape
# Out:
# (712, 48)

# %%
json.to_json('dataframe.json')

# %%
nested_json = """{
"water_points": [

  {
  number_functional: …,
number_water_points: {
communityA: …,
},
community_ranking: …
  }
  ]
}"""

# %%
import json
from pandas.io.json import json_normalize

nested = json.loads(nested_json)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-14-b9f648b48396> in <module>
#       2 from pandas.io.json import json_normalize
#       3
# ----> 4 nested = json.loads(nested_json)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_json (r'https://raw.githubusercontent.com/onaio/ona-tech/master/data/water_points.json')

# %%
print (df)
# Out:
#     water_pay                 respondent research_asst_name water_used_season  \
# 0          no                  community    Haruna Mohammed        year_round
# 1          no                  community     Haruna Mohmmed        year_round
# 2          no                  community    Haruna Mohammed        year_round
# 3          no                  community    Haruna Mohammed        year_round
# 4          no                  community    Haruna Mohammed        year_round
# ..        ...                        ...                ...               ...
# 707        no                  community         Emmanuel y        year_round
# 708        no  local_authority community         Emmanuel y        year_round
# 709        no  local_authority community         Emmanuel y        year_round
# 710        no                  community          abu seidu        year_round
# 711        no                  community                 Sa        year_round
#
# ...

# %%
import pandas as pd
df = pd.DataFrame(columns=["community_villages", "water_functioning"])

# %%
print (df)
# Out:
# Empty DataFrame
# Columns: [community_villages, water_functioning]
# Index: []

# %%
import pandas as pd
    df = pd.DataFrame(
        {
            'column': ["community_villages"], 
            'column2':["water_functioning"],
        }
    )
# Out:
#   File "<ipython-input-31-b87ce0fb8c87>", line 2
#     df = pd.DataFrame(
#     ^
# IndentationError: unexpected indent

# %%
df = pd.read_json("water_points.json")
pd.DataFrame.from_records(df).head()
# Out:
#   water_pay respondent research_asst_name water_used_season  \
# 0        no  community    Haruna Mohammed        year_round
# 1        no  community     Haruna Mohmmed        year_round
# 2        no  community    Haruna Mohammed        year_round
# 3        no  community    Haruna Mohammed        year_round
# 4        no  community    Haruna Mohammed        year_round
#
#   _bamboo_dataset_id _deleted_at water_point_condition     _xform_id_string  \
# 0                            NaT           functioning  _08_Water_points_CV
# 1                            NaT           functioning  _08_Water_points_CV
# 2                            NaT           functioning  _08_Water_points_CV
# 3                            NaT           functioning  _08_Water_points_CV
# 4                            NaT           functioning  _08_Water_points_CV
#
#   other_point_1km                                 _attachments  ...  \
# 0              no  [north_ghana/attachments/1351696546452.jpg]  ...
# ...

# %%
pd.read_json("water_points.json").head()
# Out:
#   water_pay respondent research_asst_name water_used_season  \
# 0        no  community    Haruna Mohammed        year_round
# 1        no  community     Haruna Mohmmed        year_round
# 2        no  community    Haruna Mohammed        year_round
# 3        no  community    Haruna Mohammed        year_round
# 4        no  community    Haruna Mohammed        year_round
#
#   _bamboo_dataset_id _deleted_at water_point_condition     _xform_id_string  \
# 0                            NaT           functioning  _08_Water_points_CV
# 1                            NaT           functioning  _08_Water_points_CV
# 2                            NaT           functioning  _08_Water_points_CV
# 3                            NaT           functioning  _08_Water_points_CV
# 4                            NaT           functioning  _08_Water_points_CV
#
#   other_point_1km                                 _attachments  ...  \
# 0              no  [north_ghana/attachments/1351696546452.jpg]  ...
# ...
